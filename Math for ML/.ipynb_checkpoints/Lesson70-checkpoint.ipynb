# %%
import numpy as np

samples = []

x = 0

for _ in range(10000):

    proposal = x + np.random.normal()

    ratio = np.exp(
        -proposal**2/2
    ) / np.exp(
        -x**2/2
    )

    if np.random.rand() < min(1, ratio):
        x = proposal

    samples.append(x)

print(np.mean(samples))
# Out:
# 0.008408160951851816
