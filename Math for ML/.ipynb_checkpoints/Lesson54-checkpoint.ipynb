# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 1. Setup a dummy model and dummy data
model = nn.Linear(10, 2)
criterion = nn.MSELoss()
X = torch.randn(5, 10)
y = torch.randn(5, 2)

# --- Your original code ---
# 2. Initialize the optimizer
optimizer = optim.SGD(
    model.parameters(),
    lr=0.01,
    momentum=0.9
)
# --------------------------

# 3. The standard PyTorch training step snippet
# Clear out any gradients calculated from previous batches
optimizer.zero_grad()

# Forward pass: compute predictions
predictions = model(X)

# Compute the loss
loss = criterion(predictions, y)

# Backward pass: compute the gradients of the loss w.r.t. parameters
loss.backward()

# Update the weights using our SGD + Momentum logic
optimizer.step()

print(f"Current Training Loss: {loss.item():.4f}")
# Out:
# Current Training Loss: 1.1207

# %%
optimizer = optim.Adam(
    model.parameters(),
    lr=1e-3
)

# %%
optimizer = optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=0.01
)

# %%
scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=100
)
