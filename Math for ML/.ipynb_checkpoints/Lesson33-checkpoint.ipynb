# %%
import numpy as np

A = np.array([
    [4,2],
    [1,3]
])

eigenvalues, eigenvectors = np.linalg.eig(A)

print("Eigenvalues:")
print(eigenvalues)

print("\nEigenvectors:")
print(eigenvectors)
# Out:
# Eigenvalues:
# [5. 2.]
#
# Eigenvectors:
# [[ 0.89442719 -0.70710678]
#  [ 0.4472136   0.70710678]]
