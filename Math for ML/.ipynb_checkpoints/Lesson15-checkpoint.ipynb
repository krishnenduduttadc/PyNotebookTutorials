# %%
import torch
import torch.nn as nn

layer = nn.Linear(100,50)

nn.init.xavier_uniform_(layer.weight)
# Out:
# Parameter containing:
# tensor([[-0.1600,  0.0156,  0.0043,  ..., -0.0760,  0.0185, -0.0938],
#         [ 0.1559, -0.1993,  0.0914,  ...,  0.1699,  0.1054,  0.1209],
#         [ 0.1293,  0.1062, -0.1293,  ...,  0.1021,  0.1774,  0.1463],
#         ...,
#         [-0.1020,  0.1977, -0.1017,  ..., -0.1576,  0.1524,  0.1015],
#         [-0.1906, -0.1084, -0.0155,  ...,  0.0357,  0.1097,  0.1071],
#         [ 0.1590,  0.1952,  0.1221,  ...,  0.1514, -0.0198,  0.0592]],
#        requires_grad=True)

# %%
import torch
import torch.nn as nn

layer = nn.Linear(100,50)

nn.init.kaiming_uniform_(
    layer.weight,
    nonlinearity='relu'
)
# Out:
# Parameter containing:
# tensor([[-0.0486, -0.1935,  0.1649,  ..., -0.1713,  0.0963, -0.1984],
#         [ 0.0425, -0.0792,  0.2137,  ..., -0.1208, -0.0545, -0.1499],
#         [ 0.1204, -0.0703, -0.1157,  ..., -0.1077,  0.0460, -0.0107],
#         ...,
#         [ 0.0910, -0.1094, -0.2176,  ..., -0.0835,  0.0398,  0.1617],
#         [ 0.0416, -0.0922,  0.1281,  ..., -0.2329, -0.2145,  0.2281],
#         [ 0.1313, -0.1997,  0.1161,  ...,  0.1561, -0.2375, -0.1721]],
#        requires_grad=True)

# %%
import torch.nn as nn

bn = nn.BatchNorm1d(100)

# %%
import torch.nn as nn

ln = nn.LayerNorm(100)
