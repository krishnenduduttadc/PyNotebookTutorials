# %%
import networkx as nx

G = nx.Graph()

G.add_edge("Alice","Bob")
G.add_edge("Alice","Charlie")

print(G.nodes())
print(G.edges())
# Out:
# ['Alice', 'Bob', 'Charlie']
# [('Alice', 'Bob'), ('Alice', 'Charlie')]
