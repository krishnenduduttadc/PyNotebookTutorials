# %%
from scipy.stats import beta

alpha = 1
beta_param = 1

heads = 4
tails = 1

posterior = beta(
    alpha + heads,
    beta_param + tails
)

# %%
heads = 40
tails = 10

p_mle = heads/(heads+tails)

print(p_mle)
# Out:
# 0.8
