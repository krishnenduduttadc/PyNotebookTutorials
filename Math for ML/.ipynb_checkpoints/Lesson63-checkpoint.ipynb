# %%
import numpy as np

P = np.array([
    [0.8, 0.2],
    [0.4, 0.6]
])

v = np.array([1, 0])

for day in range(10):
    v = v @ P
    print(day+1, v)
# Out:
# 1 [0.8 0.2]
# 2 [0.72 0.28]
# 3 [0.688 0.312]
# 4 [0.6752 0.3248]
# 5 [0.67008 0.32992]
# 6 [0.668032 0.331968]
# 7 [0.6672128 0.3327872]
# 8 [0.66688512 0.33311488]
# 9 [0.66675405 0.33324595]
# 10 [0.66670162 0.33329838]

# %%
import numpy as np

A = np.array([
    [0.7,0.3],
    [0.4,0.6]
])

B = np.array([
    [0.1,0.9],
    [0.8,0.2]
])

pi = np.array([0.8,0.2])

print("Transition Matrix")
print(A)

print("Emission Matrix")
print(B)
# Out:
# Transition Matrix
# [[0.7 0.3]
#  [0.4 0.6]]
# Emission Matrix
# [[0.1 0.9]
#  [0.8 0.2]]
