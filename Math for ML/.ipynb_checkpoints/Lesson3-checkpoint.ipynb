# %%
import numpy as np

v = np.array([3, 4])

length = np.linalg.norm(v)

print(length)
# Out:
# 5.0

# %%
import numpy as np

a = np.array([1,2,3])

b = np.array([4,5,6])

print(np.dot(a,b))
# Out:
# 32

# %%
x = 4
y = 3

lr = 0.1

for i in range(20):

    dx = 2*x
    dy = 2*y

    x = x - lr*dx
    y = y - lr*dy

    print(i, round(x,4), round(y,4))
# Out:
# 0 3.2 2.4
# 1 2.56 1.92
# 2 2.048 1.536
# 3 1.6384 1.2288
# 4 1.3107 0.983
# 5 1.0486 0.7864
# 6 0.8389 0.6291
# 7 0.6711 0.5033
# 8 0.5369 0.4027
# 9 0.4295 0.3221
# 10 0.3436 0.2577
# 11 0.2749 0.2062
# 12 0.2199 0.1649
# 13 0.1759 0.1319
# 14 0.1407 0.1056
# 15 0.1126 0.0844
# 16 0.0901 0.0676
# 17 0.0721 0.054
# 18 0.0576 0.0432
# 19 0.0461 0.0346
