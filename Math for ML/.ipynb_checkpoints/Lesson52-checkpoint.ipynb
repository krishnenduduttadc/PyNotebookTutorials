# %%
import numpy as np

p = np.array([0.5,0.5])

entropy = -np.sum(
    p*np.log2(p)
)

print(entropy)
# Out:
# 1.0

# %%
import numpy as np

target = 1
prediction = 0.9

loss = -np.log(prediction)

print(loss)
# Out:
# 0.10536051565782628
