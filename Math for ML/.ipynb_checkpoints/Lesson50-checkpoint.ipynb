# %%
import numpy as np

x = np.random.normal(
    loc=0,
    scale=1,
    size=10000
)

print(x.mean())
print(x.std())
# Out:
# -0.009310956710884511
# 0.9996215414965209

# %%
import numpy as np

x = np.random.binomial(
    n=10,
    p=0.5,
    size=10000
)

print(x.mean())
# Out:
# 5.0171
