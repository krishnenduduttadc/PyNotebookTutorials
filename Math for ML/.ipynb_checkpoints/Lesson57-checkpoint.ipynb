# %%
import numpy as np

P = np.array([
 [0.7,0.3],
 [0.4,0.6]
])

state = np.array([1,0])

for _ in range(5):
    state = state @ P
    print(state)
# Out:
# [0.7 0.3]
# [0.61 0.39]
# [0.583 0.417]
# [0.5749 0.4251]
# [0.57247 0.42753]

# %%
import numpy as np

samples = np.random.randn(100000)

print(samples.mean())
# Out:
# -0.0038189052306583566
