# %%
import torch
import torch.nn as nn

model = nn.Linear(10,1)

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

for epoch in range(100):
    optimizer.zero_grad()

    loss = model(
        torch.randn(5,10)
    ).mean()

    loss.backward()

    optimizer.step()
