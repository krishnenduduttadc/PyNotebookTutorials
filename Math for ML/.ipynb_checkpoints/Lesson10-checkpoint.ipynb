# %%
x = 2
w = 3
y = 1

z = w*x
a = z

loss = (a-y)**2

dL_da = 2*(a-y)
da_dz = 1
dz_dw = x

gradient = dL_da * da_dz * dz_dw

print("Gradient:", gradient)
# Out:
# Gradient: 20

# %%
def relu(x):
    return max(0, x)

print(relu(2))
# Out:
# 2

# %%
import numpy as np

X = np.array([[2,3]])

W = np.array([
    [0.5],
    [0.2]
])

b = 1

Z = X @ W + b

print(Z)
# Out:
# [[2.6]]
