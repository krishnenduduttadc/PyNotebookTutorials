# %%
# !pip install mcp httpx pydantic
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\KRISHNENDU\\anaconda3\\envs\\etl-pipeline\\Lib\\site-packages\\pywin32_system32\\pythoncom310.dll'
# Consider using the `--user` option or check the permissions.
#   Using cached mcp-1.26.0-py3-none-any.whl.metadata (89 kB)
# ...
#   Using cached python_multipart-0.0.21-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached pywin32-311-cp310-cp310-win_amd64.whl.metadata (10 kB)
# ...
#   Using cached sse_starlette-3.2.0-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached mcp-1.26.0-py3-none-any.whl (233 kB)
# Using cached python_multipart-0.0.21-py3-none-any.whl (24 kB)
# Using cached pywin32-311-cp310-cp310-win_amd64.whl (9.6 MB)
# Using cached sse_starlette-3.2.0-py3-none-any.whl (12 kB)
# ...
#
#   Attempting uninstall: pywin32
#
#     Found existing installation: pywin32 308
#
#     Uninstalling pywin32-308:
#
#    ---------------------------------------- 0/4 [pywin32]
# ...
