# %%
# in Jupyter cell
# %pip install boto3
# Out:
# ...
#    ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#    --------- ------------------------------ 3.4/14.0 MB 16.7 MB/s eta 0:00:01
#    ------------------- -------------------- 6.8/14.0 MB 16.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.2/14.0 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------ --- 12.8/14.0 MB 15.8 MB/s eta 0:00:01
#    ---------------------------------------- 14.0/14.0 MB 14.7 MB/s eta 0:00:00
# ...
#
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
# ...
