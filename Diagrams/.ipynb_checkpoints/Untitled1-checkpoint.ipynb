# %%
from diagrams import Diagram, Cluster
from diagrams.aws.compute import EC2, EC2AutoScaling, Lambda
from diagrams.aws.database import Dynamodb, ElastiCache
from diagrams.aws.storage import S3, Glacier
from diagrams.aws.network import ALB, NLB, WAF
from diagrams.aws.iot import IotCore
from diagrams.aws.analytics import KinesisDataStreams
from diagrams.aws.integration import SQS, SNS
from diagrams.aws.ml import Sagemaker
from diagrams.aws.security import KMS, IAM
from diagrams.aws.management import Cloudwatch
from diagrams.onprem.iot import Iot

# Simple test diagram first
with Diagram("Simple AWS Test", show=True, direction="TB"):
    ec2 = EC2("EC2 Instance")
    s3 = S3("S3 Bucket")
    ec2 >> s3

print("If you see AWS icons above, Graphviz is working!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 from diagrams.aws.compute import EC2, EC2AutoScaling, Lambda
#       3 from diagrams.aws.database import Dynamodb, ElastiCache
# ----> 4 from diagrams.aws.storage import S3, Glacier
#       5 from diagrams.aws.network import ALB, NLB, WAF
#       6 from diagrams.aws.iot import IotCore
#
# ImportError: cannot import name 'Glacier' from 'diagrams.aws.storage' (C:\Users\KRISHNENDU\anaconda3\Lib\site-packages\diagrams\aws\storage.py)
