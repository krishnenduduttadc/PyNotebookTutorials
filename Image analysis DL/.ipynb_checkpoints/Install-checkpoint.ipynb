# %%
# !pip install numpy pandas scikit-learn scipy matplotlib seaborn
# !pip install tensorflow==2.17.0
# !pip install keras==3.4.1
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install ultralytics
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.17.0 (from versions: 2.20.0rc0, 2.20.0)
# ERROR: No matching distribution found for tensorflow==2.17.0
# ...
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached polars-1.34.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached polars_runtime_32-1.34.0-cp39-abi3-win_amd64.whl.metadata (1.5 kB)
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 10.5 MB/s  0:00:00
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.6 MB 15.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 16.3 MB/s eta 0:00:01
# ...

# %%
# !pip install plotly bokeh altair missingno

# %%
# !pip install statsmodels sympy

# %%
# !pip install diagrams graphviz pydot networkx pygraphviz
# Out:
# ...
#   Using cached diagrams-0.24.4-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached pre_commit-4.3.0-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# ...
# Using cached diagrams-0.24.4-py3-none-any.whl (27.8 MB)
# Using cached graphviz-0.20.3-py3-none-any.whl (47 kB)
# Using cached pre_commit-4.3.0-py2.py3-none-any.whl (220 kB)
# ...
# Using cached cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# ...

# %%
# !pip install mlflow optuna shap lime
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    ----------- ---------------------------- 2.6/8.8 MB 13.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.2/8.8 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.8/8.8 MB 14.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 16.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 16.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/752.6 kB ? eta -:--:--
#    ---------------------------------------- 752.6/752.6 kB 16.5 MB/s  0:00:00
# ...

# %%
# !pip install nltk spacy transformers sentencepiece
# !python -m spacy download en_core_web_sm
# Out:
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# ...
#   Using cached safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# ...
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.9/13.9 MB 15.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.8/13.9 MB 14.6 MB/s eta 0:00:01
# ...

# %%
# !pip install opencv-python pillow scikit-image mediapipe
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement mediapipe (from versions: none)
# ERROR: No matching distribution found for mediapipe

# %%
# !pip install tqdm joblib requests beautifulsoup4 lxml

# %%
# !pip install jupyterlab ipywidgets notebook nbformat
# Out:
# ...
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached lark-1.3.0-py3-none-any.whl.metadata (1.8 kB)
# ...
# Using cached rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Using cached lark-1.3.0-py3-none-any.whl (113 kB)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# ...
#
#    ------------- -------------------------- 2/6 [lark]
#    -------------------- ------------------- 3/6 [fqdn]
#    ---------------------------------------- 6/6 [isoduration]
#
# ...

# %%
# !pip show tensorflow keras torch ultralytics diagrams graphviz
# Out:
# Name: tensorflow
# Version: 2.20.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: C:\Users\KRISHNENDU\AppData\Roaming\Python\Python313\site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google_pasta, grpcio, h5py, keras, libclang, ml_dtypes, numpy, opt_einsum, packaging, protobuf, requests, setuptools, six, tensorboard, termcolor, typing_extensions, wrapt
# Required-by:
# ---
# Name: keras
# Version: 3.4.1
# Summary: Multi-backend Keras.
# Home-page: https://github.com/keras-team/keras
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache License 2.0
# Location: C:\Users\KRISHNENDU\AppData\Roaming\Python\Python313\site-packages
# Requires: absl-py, h5py, ml-dtypes, namex, numpy, optree, packaging, rich
# Required-by: tensorflow
# ---
# Name: torch
# Version: 2.9.0+cpu
# ...

# %%
from diagrams import Diagram, Node

# Simple test diagram
with Diagram("Test Diagram", show=False):
    Node("Client") >> Node("Server")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from diagrams import Diagram, Node
#       3 # Simple test diagram
#       4 with Diagram("Test Diagram", show=False):
#
# ModuleNotFoundError: No module named 'diagrams'

# %%
import sys
# !{sys.executable} -m pip install diagrams python-graphviz
# Out:
# ...
#   Using cached diagrams-0.24.4-py3-none-any.whl.metadata (7.3 kB)
# ERROR: Could not find a version that satisfies the requirement python-graphviz (from versions: none)
# ERROR: No matching distribution found for python-graphviz

# %%
# !{sys.executable} -m pip show diagrams
# Out:
# WARNING: Package(s) not found: diagrams
