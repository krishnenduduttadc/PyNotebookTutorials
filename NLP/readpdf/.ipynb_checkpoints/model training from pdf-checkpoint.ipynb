# %%
# !pip install pypdf sentence-transformers faiss-cpu transformers
# !pip install tf-keras
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.31.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.11.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.2.6)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.8.2)
# Requirement already satisfied: pillow in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.1.0)
# Requirement already satisfied: namex in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 10.2 MB/s eta 0:00:00
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.20.1

# %%
# Step 1: Install dependencies (run once per environment)
import os
os.environ["USE_TF"] = "0"  # Disable TensorFlow/Keras backend


# Step 2: Import libraries

import faiss
import numpy as np
from pypdf import PdfReader
from sentence_transformers import SentenceTransformer
from transformers import pipeline

# Step 3: Read PDF
pdf_path = "input.pdf"  # file in current folder
reader = PdfReader(pdf_path)

# Extract text
text = ""
for page in reader.pages:
    text += page.extract_text() + "\n"

print("Total characters extracted:", len(text))

# Step 4: Chunk text into smaller pieces (for embeddings)
def chunk_text(text, chunk_size=200, overlap=50):
    words = text.split()
    chunks = []
    start = 0
    while start < len(words):
        end = start + chunk_size
        chunk = " ".join(words[start:end])
        chunks.append(chunk)
        start += chunk_size - overlap
    return chunks

chunks = chunk_text(text)
print(f"Number of chunks: {len(chunks)}")

# Step 5: Create embeddings with SentenceTransformer
#embedder = SentenceTransformer('all-MiniLM-L6-v2')
embedder = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')

embeddings = embedder.encode(chunks, convert_to_numpy=True)

# Step 6: Store in FAISS index
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# Step 7: Load a Question-Answering pipeline
qa_model = pipeline("question-answering", model="deepset/roberta-base-squad2")

# Step 8: Function to query the model
def answer_question(question, top_k=5):
    # Find most similar chunks
    q_embedding = embedder.encode([question], convert_to_numpy=True)
    distances, indices = index.search(q_embedding, top_k)
    context = " ".join([chunks[i] for i in indices[0]])

    # Get answer from QA model
    result = qa_model(question=question, context=context)
    return result["answer"]

# Example Q&A
print(answer_question("What is the main topic of this document?"))

# Step 9: Save model for deployment
embedder.save("embedding_model")
from transformers import AutoModelForQuestionAnswering, AutoTokenizer
model_name = "deepset/roberta-base-squad2"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

model.save_pretrained("qa_model")
tokenizer.save_pretrained("qa_model")

print("Models saved in 'embedding_model' and 'qa_model'.")
# Out:
# Total characters extracted: 3126
# Number of chunks: 3
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\KRISHNENDU\.cache\huggingface\hub\models--sentence-transformers--multi-qa-MiniLM-L6-cos-v1. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Fetching 0 files: 0it [00:00, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 0 files: 0it [00:00, ?it/s]
# Device set to use cpu
# hello java hello world
# Models saved in 'embedding_model' and 'qa_model'.

# %%
# Ask your question
question = "What is Hashing?"
answer = answer_question(question)

# Print it nicely
print("Q:", question)
print("A:", answer)
# Out:
# Q: What is Hashing?
# A: boosts performance
