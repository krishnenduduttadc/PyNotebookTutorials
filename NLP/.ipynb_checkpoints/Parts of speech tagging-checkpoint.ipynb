# %%
import nltk
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")

sentence = "I love natural language processing."

tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)

pos_tags
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KRISHNENDU\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\KRISHNENDU\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 8
#       5 sentence = "I love natural language processing."
#       7 tokens = nltk.word_tokenize(sentence)
# ----> 8 pos_tags = nltk.pos_tag(tokens)
#      10 pos_tags
#
# File ~\anaconda3\envs\etl-pipeline\lib\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\anaconda3\envs\etl-pipeline\lib\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\anaconda3\envs\etl-pipeline\lib\site-packages\nltk\tag\perceptron.py:183, in PerceptronTagger.__init__(self, load, lang)
#     181 self.classes = set()
#     182 if load:
# --> 183     self.load_from_json(lang)
#
# File ~\anaconda3\envs\etl-pipeline\lib\site-packages\nltk\tag\perceptron.py:273, in PerceptronTagger.load_from_json(self, lang)
#     271 def load_from_json(self, lang="eng"):
#     272     # Automatically find path to the tagger if location is not specified.
# --> 273     loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     274     with open(loc + TAGGER_JSONS[lang]["weights"]) as fin:
#     275         self.model.weights = json.load(fin)
#
# File ~\anaconda3\envs\etl-pipeline\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng/
#
#   Searched in:
#     - 'C:\\Users\\KRISHNENDU/nltk_data'
#     - 'C:\\Users\\KRISHNENDU\\anaconda3\\envs\\etl-pipeline\\nltk_data'
#     - 'C:\\Users\\KRISHNENDU\\anaconda3\\envs\\etl-pipeline\\share\\nltk_data'
#     - 'C:\\Users\\KRISHNENDU\\anaconda3\\envs\\etl-pipeline\\lib\\nltk_data'
#     - 'C:\\Users\\KRISHNENDU\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (0.17.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (78.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: wrapt in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\krishnendu\anaconda3\envs\etl-pipeline\lib\site-packages (from jinja2->spacy) (3.0.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 3.4 MB/s eta 0:00:04
#      --------- ------------------------------ 3.1/12.8 MB 8.0 MB/s eta 0:00:02
#      ------------- -------------------------- 4.5/12.8 MB 9.3 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 11.2 MB/s eta 0:00:01
#      ------------------------------- ------- 10.5/12.8 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 10.4 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp("I love natural language processing.")

[(token.text, token.pos_) for token in doc]
# Out:
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# [('I', 'PRON'),
#  ('love', 'VERB'),
#  ('natural', 'ADJ'),
#  ('language', 'NOUN'),
#  ('processing', 'NOUN'),
#  ('.', 'PUNCT')]
