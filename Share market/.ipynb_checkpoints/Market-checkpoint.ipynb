# %%
# !pip install pandas numpy matplotlib yfinance mplfinance ta seaborn jupyter
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29497 sha256=a6a1aebd6be55595230b50284cb2edc2956bf22a7bb3a3cfe539941a3538a509
#   Stored in directory: c:\users\krishnendu\appdata\local\pip\cache\wheels\5c\a1\5f\c6b85a7d9452057be4ce68a8e45d77ba34234a6d46581777c6
# Successfully built ta
# ...
#
#    ---------------------------------------- 0/4 [lark]
#    ---------------------------------------- 0/4 [lark]
#    ---------------------------------------- 0/4 [lark]
#    -------------------- ------------------- 2/4 [ta]
#    ------------------------------ --------- 3/4 [mplfinance]
#    ------------------------------ --------- 3/4 [mplfinance]
#    ------------------------------ --------- 3/4 [mplfinance]
#    ---------------------------------------- 4/4 [mplfinance]
#
# ...

# %%
# !pip install nsepy nsetools
# Out:
# ...
#   Using cached nsepy-0.8.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36104 sha256=a1ab0ad31508135364a55ab91100f8b866799352555b667941f7fb62f11acafd
#   Stored in directory: c:\users\krishnendu\appdata\local\pip\cache\wheels\ba\d6\a0\a2c830ea2a083f15d9790732c1908625dd6314a02f09a92130
# Successfully built nsepy
# ...
#
#    ------------- -------------------------- 1/3 [nsetools]
#    -------------------------- ------------- 2/3 [nsepy]
#    -------------------------- ------------- 2/3 [nsepy]
#    ---------------------------------------- 3/3 [nsepy]
#
# ...

# %% [markdown]
# Fetch historical OHLC data (yfinance)

# %%
# Cell 1: imports
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf


# Cell 2: fetch data (change ticker and dates as needed)
ticker = 'RELIANCE.NS' # example: Reliance Industries on NSE
start = '2023-01-01'
end = '2025-09-16'


df = yf.download(ticker, start=start, end=end, progress=False)
# show head
df.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2023-01-02  1175.889648  1177.304802  1163.244669  1164.066352     5316175
# 2023-01-03  1167.284668  1174.565828  1163.062148  1170.936659     7658932
# 2023-01-04  1149.709595  1169.110728  1147.632506  1167.261851     9264891
# 2023-01-05  1147.655273  1157.858026  1143.067494  1151.969199    13637099
# 2023-01-06  1158.086304  1163.130627  1149.595501  1153.407240     6349597

# %% [markdown]
# Simple candlestick chart with moving averages

# %%
import yfinance as yf
import pandas as pd
import mplfinance as mpf


# fetch data
ticker = 'RELIANCE.NS'
start = '2023-01-01'
end = '2025-09-16'


df = yf.download(ticker, start=start, end=end, progress=False)


# clean numeric columns
cols = ['Open','High','Low','Close','Adj Close','Volume']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df = df.dropna()


# calculate moving averages
df['MA20'] = df['Close'].rolling(20).mean()
df['MA50'] = df['Close'].rolling(50).mean()


# plot candlestick with MAs
mpf.plot(df.tail(120), type='candle', volume=True,
mav=(20,50), style='yahoo', title=f"{ticker} - Candlestick w/ MAs")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 17
#      15 # clean numeric columns
#      16 cols = ['Open','High','Low','Close','Adj Close','Volume']
# ---> 17 df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
#      18 df = df.dropna()
#      21 # calculate moving averages
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2782, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2779 if len(keyarr) and not isinstance(keyarr[0], tuple):
# ...
