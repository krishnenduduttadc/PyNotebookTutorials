# %%
# !pip install langchain langchain-ollama
# !pip install langchain langchain-community ollama
# Out:
# Collecting langchain
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-ollama
#   Using cached langchain_ollama-0.3.8-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Using cached langchain_core-0.3.76-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Using cached langsmith-0.4.28-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\krishnendu\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\krishnendu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\krishnendu\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Collecting ollama<1.0.0,>=0.5.3 (from langchain-ollama)
#   Using cached ollama-0.5.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in c:\users\krishnendu\anaconda3\lib\site-packages (from ollama<1.0.0,>=0.5.3->langchain-ollama) (0.28.1)
# Requirement already satisfied: anyio in c:\users\krishnendu\anaconda3\lib\site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\krishnendu\anaconda3\lib\site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\krishnendu\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (0.16.0)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.3-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\krishnendu\anaconda3\lib\site-packages (from anyio->httpx>=0.27->ollama<1.0.0,>=0.5.3->langchain-ollama) (1.3.0)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.76-py3-none-any.whl (447 kB)
# Using cached langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Using cached langchain_ollama-0.3.8-py3-none-any.whl (25 kB)
# Using cached ollama-0.5.4-py3-none-any.whl (13 kB)
# Using cached langsmith-0.4.28-py3-none-any.whl (384 kB)
# Downloading orjson-3.11.3-cp312-cp312-win_amd64.whl (131 kB)
# Installing collected packages: orjson, ollama, langsmith, langchain-core, langchain-text-splitters, langchain-ollama, langchain
#
#    ----------- ---------------------------- 2/7 [langsmith]
#    ----------- ---------------------------- 2/7 [langsmith]
#    ----------- ---------------------------- 2/7 [langsmith]
#    ----------- ---------------------------- 2/7 [langsmith]
#    ----------- ---------------------------- 2/7 [langsmith]
#    ----------- ---------------------------- 2/7 [langsmith]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-text-splitters]
#    ---------------------------- ----------- 5/7 [langchain-ollama]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------------- 7/7 [langchain]
#
# Successfully installed langchain-0.3.27 langchain-core-0.3.76 langchain-ollama-0.3.8 langchain-text-splitters-0.3.11 langsmith-0.4.28 ollama-0.5.4 orjson-3.11.3
# Requirement already satisfied: langchain in c:\users\krishnendu\anaconda3\lib\site-packages (0.3.27)
# Collecting langchain-community
#   Using cached langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: ollama in c:\users\krishnendu\anaconda3\lib\site-packages (0.5.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (0.4.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\krishnendu\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\krishnendu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishnendu\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\krishnendu\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-community) (3.12.15)
# Collecting dataclasses-json<0.7,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\krishnendu\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\krishnendu\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\krishnendu\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: httpx>=0.27 in c:\users\krishnendu\anaconda3\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: anyio in c:\users\krishnendu\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\krishnendu\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\krishnendu\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\krishnendu\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\krishnendu\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\krishnendu\anaconda3\lib\site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)
# Using cached langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: typing-inspect, marshmallow, httpx-sse, dataclasses-json, pydantic-settings, langchain-community
#
#    ------ --------------------------------- 1/6 [marshmallow]
#    ------------- -------------------------- 2/6 [httpx-sse]
#   Attempting uninstall: pydantic-settings
#    ------------- -------------------------- 2/6 [httpx-sse]
#    -------------------------- ------------- 4/6 [pydantic-settings]
#     Found existing installation: pydantic-settings 2.6.1
#    -------------------------- ------------- 4/6 [pydantic-settings]
#     Uninstalling pydantic-settings-2.6.1:
#    -------------------------- ------------- 4/6 [pydantic-settings]
#       Successfully uninstalled pydantic-settings-2.6.1
#    -------------------------- ------------- 4/6 [pydantic-settings]
#    -------------------------- ------------- 4/6 [pydantic-settings]
#    -------------------------- ------------- 4/6 [pydantic-settings]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    --------------------------------- ------ 5/6 [langchain-community]
#    ---------------------------------------- 6/6 [langchain-community]
#
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.1 langchain-community-0.3.29 marshmallow-3.26.1 pydantic-settings-2.10.1 typing-inspect-0.9.0

# %%
from langchain_ollama import OllamaLLM

# Load local model (llama3 is default, you can also try mistral, gemma, etc.)
llm = OllamaLLM(model="llama3")

# Test
response = llm.invoke("Hello, what is 5 * 5?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[6], line 7
#       4 llm = OllamaLLM(model="llama3")
#       6 # Test
# ----> 7 response = llm.invoke("Hello, what is 5 * 5?")
#       8 print(response)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:390, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     379 @override
#     380 def invoke(
#     381     self,
#    (...)
#     386     **kwargs: Any,
#     387 ) -> str:
#     388     config = ensure_config(config)
#     389     return (
# --> 390         self.generate_prompt(
#     391             [self._convert_input(input)],
#     392             stop=stop,
#     393             callbacks=config.get("callbacks"),
#     394             tags=config.get("tags"),
#     395             metadata=config.get("metadata"),
#     396             run_name=config.get("run_name"),
#     397             run_id=config.pop("run_id", None),
#     398             **kwargs,
#     399         )
#     400         .generations[0][0]
#     401         .text
#     402     )
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:789, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     780 @override
#     781 def generate_prompt(
#     782     self,
#    (...)
#     786     **kwargs: Any,
#     787 ) -> LLMResult:
#     788     prompt_strings = [p.to_string() for p in prompts]
# --> 789     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:1000, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     985 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     986     run_managers = [
#     987         callback_manager.on_llm_start(
#     988             self._serialized,
#    (...)
#     998         )
#     999     ]
# -> 1000     return self._generate_helper(
#    1001         prompts,
#    1002         stop,
#    1003         run_managers,
#    1004         new_arg_supported=bool(new_arg_supported),
#    1005         **kwargs,
#    1006     )
#    1007 if len(missing_prompts) > 0:
#    1008     run_managers = [
#    1009         callback_managers[idx].on_llm_start(
#    1010             self._serialized,
#    (...)
#    1017         for idx in missing_prompt_idxs
#    1018     ]
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\llms.py:815, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     804 def _generate_helper(
#     805     self,
#     806     prompts: list[str],
#    (...)
#     811     **kwargs: Any,
#     812 ) -> LLMResult:
#     813     try:
#     814         output = (
# --> 815             self._generate(
#     816                 prompts,
#     817                 stop=stop,
#     818                 # TODO: support multiple run managers
#     819                 run_manager=run_managers[0] if run_managers else None,
#     820                 **kwargs,
#     821             )
#     822             if new_arg_supported
#     823             else self._generate(prompts, stop=stop)
#     824         )
#     825     except BaseException as e:
#     826         for run_manager in run_managers:
#
# File ~\anaconda3\Lib\site-packages\langchain_ollama\llms.py:443, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     441 generations = []
#     442 for prompt in prompts:
# --> 443     final_chunk = self._stream_with_aggregation(
#     444         prompt,
#     445         stop=stop,
#     446         run_manager=run_manager,
#     447         verbose=self.verbose,
#     448         **kwargs,
#     449     )
#     450     generations.append([final_chunk])
#     451 return LLMResult(generations=generations)
#
# File ~\anaconda3\Lib\site-packages\langchain_ollama\llms.py:402, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     400 final_chunk = None
#     401 thinking_content = ""
# --> 402 for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     403     if not isinstance(stream_resp, str):
#     404         if stream_resp.get("thinking"):
#
# File ~\anaconda3\Lib\site-packages\langchain_ollama\llms.py:346, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     339 def _create_generate_stream(
#     340     self,
#     341     prompt: str,
#     342     stop: Optional[list[str]] = None,
#     343     **kwargs: Any,
#     344 ) -> Iterator[Union[Mapping[str, Any], str]]:
#     345     if self._client:
# --> 346         yield from self._client.generate(
#     347             **self._generate_params(prompt, stop=stop, **kwargs)
#     348         )
#
# File ~\anaconda3\Lib\site-packages\ollama\_client.py:175, in Client._request.<locals>.inner()
#     173 part = json.loads(line)
#     174 if err := part.get('error'):
# --> 175   raise ResponseError(err)
#     176 yield cls(**part)
#
# ResponseError: model runner has unexpectedly stopped, this may be due to resource limitations or an internal error, check ollama server logs for details (status code: -1)
