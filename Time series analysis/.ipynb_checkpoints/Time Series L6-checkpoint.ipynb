# %% [markdown]
# What LSTM DOES WELL
#
# ✔ Captures non-linear temporal patterns
# ✔ Handles sequences naturally
# ✔ Powerful for structured time series
#
# ❌ What LSTM DOES POORLY (IN MARKETS)
#
# ❌ Overfits easily
# ❌ Sensitive to regime changes
# ❌ Poor interpretability
# ❌ No economic understanding

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

plt.style.use("seaborn-v0_8")
# Out:
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# Load Stock Data

# %%
ticker = "RELIANCE.NS"

df = yf.download(
    ticker,
    start="2015-01-01",
    end="2025-01-01"
)

df = df[['Close']].dropna()
df.head()
# Out:
# C:\Users\KRISHNENDU\AppData\Local\Temp\ipykernel_20888\3164813451.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# [*********************100%***********************]  1 of 1 completed
# Price            Close
# Ticker     RELIANCE.NS
# Date
# 2015-01-01  189.999817
# 2015-01-02  189.496933
# 2015-01-05  187.421249
# 2015-01-06  178.915237
# 2015-01-07  182.809814

# %% [markdown]
# Scale the Data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(df[['Close']])

# %% [markdown]
# Create Sequences (Sliding Window)

# %%
def create_sequences(data, window_size=60):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, window_size=60)

X.shape, y.shape
# Out:
# ((2407, 60), (2407,))

# %% [markdown]
# Train–Test Split (Time-Based)

# %%
train_size = int(len(X) * 0.8)

X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# Define LSTM Architecture

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(60,1)))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mean_squared_error'
)

model.summary()
# Out:
# C:\Users\KRISHNENDU\anaconda3\envs\etl-pipeline\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 60, 50)              │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,651 (119.73 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Train the Model

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.7869e-04 - val_loss: 5.4161e-04
# Epoch 2/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.3433e-04 - val_loss: 6.4185e-04
# Epoch 3/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.7527e-04 - val_loss: 3.5608e-04
# Epoch 4/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.8573e-04 - val_loss: 7.7772e-04
# Epoch 5/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 5.9605e-04 - val_loss: 4.4328e-04
# Epoch 6/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.6886e-04 - val_loss: 5.1717e-04
# Epoch 7/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.0385e-04 - val_loss: 6.2279e-04
# Epoch 8/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.4893e-04 - val_loss: 3.8729e-04
# Epoch 9/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 5.5826e-04 - val_loss: 6.8571e-04
# Epoch 10/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.0367e-04 - val_loss: 3.6841e-04
# Epoch 11/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.9503e-04 - val_loss: 7.1549e-04
# Epoch 12/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.8483e-04 - val_loss: 7.9062e-04
# Epoch 13/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 5.2908e-04 - val_loss: 7.7850e-04
# Epoch 14/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 4.8842e-04 - val_loss: 9.9021e-04
# Epoch 15/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 4.8846e-04 - val_loss: 0.0011
# Epoch 16/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 5.3517e-04 - val_loss: 3.2416e-04
# Epoch 17/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.9221e-04 - val_loss: 3.6714e-04
# Epoch 18/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.6162e-04 - val_loss: 0.0010
# Epoch 19/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.1413e-04 - val_loss: 3.6649e-04
# Epoch 20/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.5165e-04 - val_loss: 3.8403e-04
# Epoch 21/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 4.6956e-04 - val_loss: 5.1145e-04
# Epoch 22/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3864e-04 - val_loss: 3.8918e-04
# Epoch 23/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 6.0596e-04 - val_loss: 3.1667e-04
# Epoch 24/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.0695e-04 - val_loss: 8.9234e-04
# Epoch 25/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.7552e-04 - val_loss: 4.7346e-04
# Epoch 26/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 5.1774e-04 - val_loss: 4.8604e-04
# Epoch 27/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 5.0673e-04 - val_loss: 8.3688e-04
# Epoch 28/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.6851e-04 - val_loss: 4.5660e-04
# Epoch 29/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.9812e-04 - val_loss: 5.0863e-04
# Epoch 30/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.3660e-04 - val_loss: 3.2933e-04
# Epoch 31/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.5473e-04 - val_loss: 0.0011
# Epoch 32/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 5.1409e-04 - val_loss: 4.1800e-04
# Epoch 33/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.7235e-04 - val_loss: 2.6437e-04
# Epoch 34/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.5365e-04 - val_loss: 0.0014
# Epoch 35/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.9192e-04 - val_loss: 2.6923e-04
# Epoch 36/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4931e-04 - val_loss: 6.1590e-04
# Epoch 37/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4488e-04 - val_loss: 2.7228e-04
# Epoch 38/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.5635e-04 - val_loss: 3.2262e-04
# Epoch 39/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 4.3038e-04 - val_loss: 3.4232e-04
# Epoch 40/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 4.3461e-04 - val_loss: 7.3499e-04
# Epoch 41/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.8389e-04 - val_loss: 2.4672e-04
# Epoch 42/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 5.0774e-04 - val_loss: 4.2838e-04
# Epoch 43/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.5784e-04 - val_loss: 4.7072e-04
# Epoch 44/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.4254e-04 - val_loss: 5.6854e-04
# Epoch 45/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.5044e-04 - val_loss: 2.3687e-04
# Epoch 46/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.1581e-04 - val_loss: 3.2471e-04
# Epoch 47/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 5.2866e-04 - val_loss: 3.0705e-04
# Epoch 48/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.2287e-04 - val_loss: 2.2874e-04
# Epoch 49/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 4.3939e-04 - val_loss: 5.6578e-04
# Epoch 50/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.7097e-04 - val_loss: 2.3329e-04
# Epoch 51/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 4.6101e-04 - val_loss: 3.6672e-04
# Epoch 52/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.6450e-04 - val_loss: 4.3790e-04
# Epoch 53/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.7799e-04 - val_loss: 2.4601e-04
# Epoch 54/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4428e-04 - val_loss: 2.3712e-04
# Epoch 55/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 5.0636e-04 - val_loss: 4.2027e-04
# Epoch 56/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.9186e-04 - val_loss: 3.9347e-04
# Epoch 57/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.5013e-04 - val_loss: 2.2699e-04
# Epoch 58/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.1225e-04 - val_loss: 2.5600e-04
# Epoch 59/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.2963e-04 - val_loss: 2.7651e-04
# Epoch 60/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4723e-04 - val_loss: 2.8004e-04
# Epoch 61/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.8531e-04 - val_loss: 0.0010
# Epoch 62/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.0378e-04 - val_loss: 3.5847e-04
# Epoch 63/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.1342e-04 - val_loss: 2.1819e-04
# Epoch 64/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.3842e-04 - val_loss: 2.2342e-04
# Epoch 65/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.1338e-04 - val_loss: 2.1866e-04
# Epoch 66/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.7510e-04 - val_loss: 2.2051e-04
# Epoch 67/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.2350e-04 - val_loss: 2.2287e-04
# Epoch 68/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3942e-04 - val_loss: 4.0784e-04
# Epoch 69/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4176e-04 - val_loss: 2.1599e-04
# Epoch 70/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 3.9826e-04 - val_loss: 4.3189e-04
# Epoch 71/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3378e-04 - val_loss: 3.0840e-04
# Epoch 72/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 4.0069e-04 - val_loss: 2.2034e-04
# Epoch 73/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.1802e-04 - val_loss: 2.5414e-04
# Epoch 74/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.7242e-04 - val_loss: 2.5469e-04
# Epoch 75/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4740e-04 - val_loss: 0.0011
# Epoch 76/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.2000e-04 - val_loss: 0.0014
# Epoch 77/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.2842e-04 - val_loss: 2.4140e-04
# Epoch 78/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.8188e-04 - val_loss: 5.6293e-04
# Epoch 79/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3372e-04 - val_loss: 2.2942e-04
# Epoch 80/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.8948e-04 - val_loss: 2.0545e-04
# Epoch 81/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3577e-04 - val_loss: 5.1952e-04
# Epoch 82/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3291e-04 - val_loss: 2.1179e-04
# Epoch 83/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3750e-04 - val_loss: 4.5614e-04
# Epoch 84/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - loss: 4.3026e-04 - val_loss: 2.3456e-04
# Epoch 85/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4.8294e-04 - val_loss: 2.1971e-04
# Epoch 86/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 3.8529e-04 - val_loss: 3.7676e-04
# Epoch 87/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4657e-04 - val_loss: 2.0992e-04
# Epoch 88/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 4.2006e-04 - val_loss: 7.5294e-04
# Epoch 89/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.0976e-04 - val_loss: 3.3736e-04
# Epoch 90/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 3.9539e-04 - val_loss: 2.0728e-04
# Epoch 91/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.7484e-04 - val_loss: 5.2091e-04
# Epoch 92/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3797e-04 - val_loss: 3.0391e-04
# Epoch 93/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3256e-04 - val_loss: 2.1305e-04
# Epoch 94/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 3.9747e-04 - val_loss: 2.2656e-04
# Epoch 95/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.2626e-04 - val_loss: 2.2395e-04
# Epoch 96/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.3807e-04 - val_loss: 2.7032e-04
# Epoch 97/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 3.7754e-04 - val_loss: 5.4841e-04
# Epoch 98/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 4.1089e-04 - val_loss: 2.4852e-04
# Epoch 99/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.1075e-04 - val_loss: 2.3717e-04
# Epoch 100/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 4.4712e-04 - val_loss: 2.0620e-04

# %% [markdown]
# Predict on Test Data

# %%
predictions = model.predict(X_test)

predictions = scaler.inverse_transform(predictions.reshape(-1,1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %% [markdown]
# Evaluate Performance

# %%
mae = mean_absolute_error(y_test_actual, predictions)
print("MAE:", mae)
# Out:
# MAE: 15.92109927102243

# %% [markdown]
# Plot LSTM Predictions vs Actual

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test_actual, label="Actual")
plt.plot(predictions, label="LSTM Prediction", color='red')
plt.legend()
plt.title("LSTM Forecast vs Actual")
plt.show()
