# %%
import sqlite3
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np
import os

# File paths
db_path = r"E:\police\consumer.db"
output_dir = r"E:\police\geojson_chunks"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Connect to SQLite
conn = sqlite3.connect(db_path)

# Get total rows
total_rows = conn.execute("SELECT COUNT(*) FROM consumer").fetchone()[0]
print(f"Total rows: {total_rows}")

# Chunking
chunk_size = 500000  # Adjust as needed
offset = 0
chunk_num = 1

while offset < total_rows:
    print(f"Processing rows {offset} to {offset + chunk_size}...")

    query = f"""
        SELECT * FROM consumer
        LIMIT {chunk_size} OFFSET {offset}
    """
    df = pd.read_sql_query(query, conn)

    # Clean coordinates
    df['ZLATITUDE'] = df['ZLATITUDE'].replace(r'^\s*$', np.nan, regex=True)
    df['ZLONGITUDE'] = df['ZLONGITUDE'].replace(r'^\s*$', np.nan, regex=True)
    df['ZLATITUDE'] = pd.to_numeric(df['ZLATITUDE'], errors='coerce')
    df['ZLONGITUDE'] = pd.to_numeric(df['ZLONGITUDE'], errors='coerce')
    df = df.dropna(subset=['ZLATITUDE', 'ZLONGITUDE'])

    # Convert to GeoDataFrame
    geometry = [Point(xy) for xy in zip(df['ZLONGITUDE'], df['ZLATITUDE'])]
    gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

    # Save chunk to separate GeoJSON
    chunk_file = os.path.join(output_dir, f"consumer_chunk_{chunk_num:04d}.geojson")
    gdf.to_file(chunk_file, driver="GeoJSON")
    print(f"Saved: {chunk_file}")

    offset += chunk_size
    chunk_num += 1

conn.close()
print("✅ All chunks written to:", output_dir)
# Out:
# Total rows: 24021380
# Processing rows 0 to 500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0001.geojson
# Processing rows 500000 to 1000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0002.geojson
# Processing rows 1000000 to 1500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0003.geojson
# Processing rows 1500000 to 2000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0004.geojson
# Processing rows 2000000 to 2500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0005.geojson
# Processing rows 2500000 to 3000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0006.geojson
# Processing rows 3000000 to 3500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0007.geojson
# Processing rows 3500000 to 4000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0008.geojson
# Processing rows 4000000 to 4500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0009.geojson
# Processing rows 4500000 to 5000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0010.geojson
# Processing rows 5000000 to 5500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0011.geojson
# Processing rows 5500000 to 6000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0012.geojson
# Processing rows 6000000 to 6500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0013.geojson
# Processing rows 6500000 to 7000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0014.geojson
# Processing rows 7000000 to 7500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0015.geojson
# Processing rows 7500000 to 8000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0016.geojson
# Processing rows 8000000 to 8500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0017.geojson
# Processing rows 8500000 to 9000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0018.geojson
# Processing rows 9000000 to 9500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0019.geojson
# Processing rows 9500000 to 10000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0020.geojson
# Processing rows 10000000 to 10500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0021.geojson
# Processing rows 10500000 to 11000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0022.geojson
# Processing rows 11000000 to 11500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0023.geojson
# Processing rows 11500000 to 12000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0024.geojson
# Processing rows 12000000 to 12500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0025.geojson
# Processing rows 12500000 to 13000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0026.geojson
# Processing rows 13000000 to 13500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0027.geojson
# Processing rows 13500000 to 14000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0028.geojson
# Processing rows 14000000 to 14500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0029.geojson
# Processing rows 14500000 to 15000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0030.geojson
# Processing rows 15000000 to 15500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0031.geojson
# Processing rows 15500000 to 16000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0032.geojson
# Processing rows 16000000 to 16500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0033.geojson
# Processing rows 16500000 to 17000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0034.geojson
# Processing rows 17000000 to 17500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0035.geojson
# Processing rows 17500000 to 18000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0036.geojson
# Processing rows 18000000 to 18500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0037.geojson
# Processing rows 18500000 to 19000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0038.geojson
# Processing rows 19000000 to 19500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0039.geojson
# Processing rows 19500000 to 20000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0040.geojson
# Processing rows 20000000 to 20500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0041.geojson
# Processing rows 20500000 to 21000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0042.geojson
# Processing rows 21000000 to 21500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0043.geojson
# Processing rows 21500000 to 22000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0044.geojson
# Processing rows 22000000 to 22500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0045.geojson
# Processing rows 22500000 to 23000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0046.geojson
# Processing rows 23000000 to 23500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0047.geojson
# Processing rows 23500000 to 24000000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0048.geojson
# Processing rows 24000000 to 24500000...
# Saved: E:\police\geojson_chunks\consumer_chunk_0049.geojson
# ✅ All chunks written to: E:\police\geojson_chunks

# %%
import geopandas as gpd
import os

# Folder with individual chunk files
chunk_dir = r"E:\police\geojson_chunks"
merged_output_path = r"E:\police\consumer_merged.geojson"

# Collect all .geojson chunk file paths
geojson_files = [os.path.join(chunk_dir, f) for f in os.listdir(chunk_dir) if f.endswith(".geojson")]

print(f"Found {len(geojson_files)} GeoJSON files to merge...")

# Read and concatenate all files
gdf_list = []
for file in geojson_files:
    print(f"Reading: {file}")
    gdf = gpd.read_file(file)
    gdf_list.append(gdf)

# Concatenate into one GeoDataFrame
merged_gdf = gpd.GeoDataFrame(pd.concat(gdf_list, ignore_index=True), crs="EPSG:4326")

# Write merged GeoJSON
merged_gdf.to_file(merged_output_path, driver="GeoJSON")

print(f"✅ Merged GeoJSON saved to: {merged_output_path}")
# Out:
# Found 49 GeoJSON files to merge...
# Reading: E:\police\geojson_chunks\consumer_chunk_0001.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0002.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0003.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0004.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0005.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0006.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0007.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0008.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0009.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0010.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0011.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0012.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0013.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0014.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0015.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0016.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0017.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0018.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0019.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0020.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0021.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0022.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0023.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0024.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0025.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0026.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0027.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0028.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0029.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0030.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0031.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0032.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0033.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0034.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0035.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0036.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0037.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0038.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0039.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0040.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0041.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0042.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0043.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0044.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0045.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0046.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0047.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0048.geojson
# Reading: E:\police\geojson_chunks\consumer_chunk_0049.geojson
# ✅ Merged GeoJSON saved to: E:\police\consumer_merged.geojson
